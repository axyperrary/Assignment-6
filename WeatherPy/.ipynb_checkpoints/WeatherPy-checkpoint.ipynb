# %% [markdown]
# # WeatherPy

# %% [markdown]
# ## Analysis
# - As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# - There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# - There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import CitiPy
from citipy import citipy

# Import API key
from api_keys import api_key

# Output File (CSV)
output_data_file = "cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"City Count: {len(cities)}")
# Out:
# City Count: 589

# %% [markdown]
# ## Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = "709eaff6487fadf0c26e0bc441b8c854"

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

print("Beginning Data Retrival \n-----------------------------")

for i in range(len(cities)):
    try:     
        print(f"Processing Record {i + 1} | {cities[i]}")
        query_url = url + "appid=" + api_key + "&q=" + cities[i] + "&units=imperial"
        weather_response = requests.get(query_url).json()
        cloudiness.append(weather_response["clouds"]["all"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        humidity.append(weather_response["main"]["humidity"])
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
    except:
        print("City not found. Skipping...")
    
print("----------------------------- \nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrival
# -----------------------------
# Processing Record 1 | prince rupert
# Processing Record 2 | albany
# Processing Record 3 | rikitea
# Processing Record 4 | peniche
# Processing Record 5 | mount isa
# Processing Record 6 | bonavista
# Processing Record 7 | cherskiy
# Processing Record 8 | ternate
# Processing Record 9 | busselton
# Processing Record 10 | vernon
# Processing Record 11 | abu zabad
# Processing Record 12 | nikolskoye
# Processing Record 13 | port blair
# Processing Record 14 | naze
# Processing Record 15 | ribeira grande
# Processing Record 16 | arraial do cabo
# Processing Record 17 | iqaluit
# Processing Record 18 | broome
# Processing Record 19 | mataura
# Processing Record 20 | kuche
# City not found. Skipping...
# Processing Record 21 | victoria
# Processing Record 22 | saleaula
# City not found. Skipping...
# Processing Record 23 | barrow
# Processing Record 24 | monrovia
# Processing Record 25 | batagay
# Processing Record 26 | hithadhoo
# Processing Record 27 | port elizabeth
# Processing Record 28 | hobart
# Processing Record 29 | ushuaia
# Processing Record 30 | senanga
# Processing Record 31 | avarua
# Processing Record 32 | hilo
# Processing Record 33 | ponta do sol
# Processing Record 34 | punta arenas
# Processing Record 35 | neuquen
# Processing Record 36 | port alfred
# Processing Record 37 | itamaraca
# Processing Record 38 | cape town
# Processing Record 39 | tuktoyaktuk
# Processing Record 40 | westport
# Processing Record 41 | jamestown
# Processing Record 42 | emba
# Processing Record 43 | lebanon
# Processing Record 44 | khatanga
# Processing Record 45 | chuy
# Processing Record 46 | mar del plata
# Processing Record 47 | carnarvon
# Processing Record 48 | saint george
# Processing Record 49 | doha
# Processing Record 50 | portland
# Processing Record 51 | elat
# Processing Record 52 | bluff
# Processing Record 53 | vaini
# Processing Record 54 | castro
# Processing Record 55 | lebu
# Processing Record 56 | vaitape
# Processing Record 57 | yuzhno-sukhokumsk
# Processing Record 58 | wainwright
# Processing Record 59 | ambon
# Processing Record 60 | aguimes
# Processing Record 61 | son la
# Processing Record 62 | bethel
# Processing Record 63 | kapaa
# Processing Record 64 | lorengau
# Processing Record 65 | abu kamal
# Processing Record 66 | georgetown
# Processing Record 67 | wuwei
# Processing Record 68 | hermanus
# Processing Record 69 | charters towers
# Processing Record 70 | klaksvik
# Processing Record 71 | blumberg
# Processing Record 72 | bathsheba
# Processing Record 73 | fountain hills
# Processing Record 74 | uyuni
# Processing Record 75 | taolanaro
# City not found. Skipping...
# Processing Record 76 | barinas
# Processing Record 77 | gat
# Processing Record 78 | paamiut
# Processing Record 79 | yellowknife
# Processing Record 80 | faanui
# Processing Record 81 | klyuchi
# Processing Record 82 | inongo
# Processing Record 83 | bredasdorp
# Processing Record 84 | bowen
# Processing Record 85 | yichang
# Processing Record 86 | inta
# Processing Record 87 | tautira
# Processing Record 88 | amderma
# City not found. Skipping...
# Processing Record 89 | qaanaaq
# Processing Record 90 | flin flon
# Processing Record 91 | saquarema
# Processing Record 92 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 93 | hwange
# Processing Record 94 | norman wells
# Processing Record 95 | longyearbyen
# Processing Record 96 | anadyr
# Processing Record 97 | alyangula
# Processing Record 98 | azimur
# City not found. Skipping...
# Processing Record 99 | calamar
# Processing Record 100 | port macquarie
# Processing Record 101 | qianan
# Processing Record 102 | cabo san lucas
# Processing Record 103 | lolua
# City not found. Skipping...
# Processing Record 104 | samalaeulu
# City not found. Skipping...
# Processing Record 105 | ballina
# Processing Record 106 | ancud
# Processing Record 107 | fort nelson
# Processing Record 108 | rawson
# Processing Record 109 | ulaanbaatar
# Processing Record 110 | katsuura
# Processing Record 111 | chokurdakh
# Processing Record 112 | ozgon
# City not found. Skipping...
# Processing Record 113 | provideniya
# Processing Record 114 | vaitupu
# City not found. Skipping...
# Processing Record 115 | kalmunai
# Processing Record 116 | butaritari
# Processing Record 117 | dunedin
# Processing Record 118 | sangar
# Processing Record 119 | luanda
# Processing Record 120 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 121 | east london
# Processing Record 122 | cape coast
# Processing Record 123 | haines junction
# Processing Record 124 | cayenne
# Processing Record 125 | sentyabrskiy
# City not found. Skipping...
# Processing Record 126 | chelmno
# Processing Record 127 | mahebourg
# Processing Record 128 | upernavik
# Processing Record 129 | mys shmidta
# City not found. Skipping...
# Processing Record 130 | tessalit
# Processing Record 131 | luderitz
# Processing Record 132 | zhezkazgan
# Processing Record 133 | nizhneyansk
# City not found. Skipping...
# Processing Record 134 | san patricio
# Processing Record 135 | sohag
# Processing Record 136 | cabedelo
# Processing Record 137 | saldanha
# Processing Record 138 | atuona
# Processing Record 139 | sitka
# Processing Record 140 | new norfolk
# Processing Record 141 | asau
# City not found. Skipping...
# Processing Record 142 | cidreira
# Processing Record 143 | sulangan
# Processing Record 144 | phanat nikhom
# Processing Record 145 | san quintin
# Processing Record 146 | belushya guba
# City not found. Skipping...
# Processing Record 147 | aleksandrov gay
# Processing Record 148 | montevideo
# Processing Record 149 | fortuna
# Processing Record 150 | kemijarvi
# City not found. Skipping...
# Processing Record 151 | puerto ayora
# Processing Record 152 | beloha
# Processing Record 153 | lagoa
# Processing Record 154 | tiksi
# Processing Record 155 | aitape
# Processing Record 156 | tateyama
# Processing Record 157 | pevek
# Processing Record 158 | trelew
# Processing Record 159 | the valley
# Processing Record 160 | saint-philippe
# Processing Record 161 | lompoc
# Processing Record 162 | pangnirtung
# Processing Record 163 | buraydah
# Processing Record 164 | road town
# Processing Record 165 | bandarbeyla
# Processing Record 166 | rock sound
# Processing Record 167 | meulaboh
# Processing Record 168 | sorvag
# City not found. Skipping...
# Processing Record 169 | pisco
# Processing Record 170 | presidencia roque saenz pena
# Processing Record 171 | shchelyayur
# City not found. Skipping...
# Processing Record 172 | russell
# Processing Record 173 | carutapera
# Processing Record 174 | malmesbury
# Processing Record 175 | geraldton
# Processing Record 176 | tasiilaq
# Processing Record 177 | snezhnogorsk
# Processing Record 178 | sioux lookout
# Processing Record 179 | ust-ishim
# Processing Record 180 | flinders
# Processing Record 181 | weihai
# Processing Record 182 | chagoda
# Processing Record 183 | ahuimanu
# Processing Record 184 | barentsburg
# City not found. Skipping...
# Processing Record 185 | vila velha
# Processing Record 186 | ahipara
# Processing Record 187 | san cristobal
# Processing Record 188 | muzquiz
# City not found. Skipping...
# Processing Record 189 | attawapiskat
# City not found. Skipping...
# Processing Record 190 | suwalki
# Processing Record 191 | mergui
# City not found. Skipping...
# Processing Record 192 | narsaq
# Processing Record 193 | tortoli
# Processing Record 194 | halalo
# City not found. Skipping...
# Processing Record 195 | te anau
# Processing Record 196 | puerto madero
# Processing Record 197 | turukhansk
# Processing Record 198 | ampanihy
# Processing Record 199 | sosnovo-ozerskoye
# Processing Record 200 | shingu
# Processing Record 201 | sakaiminato
# Processing Record 202 | talnakh
# Processing Record 203 | kuytun
# Processing Record 204 | nanortalik
# Processing Record 205 | matongo
# Processing Record 206 | severo-kurilsk
# Processing Record 207 | ushtobe
# Processing Record 208 | katha
# City not found. Skipping...
# Processing Record 209 | namatanai
# Processing Record 210 | lahaina
# Processing Record 211 | roald
# Processing Record 212 | namibe
# Processing Record 213 | naryan-mar
# Processing Record 214 | glendive
# Processing Record 215 | tsihombe
# City not found. Skipping...
# Processing Record 216 | clyde river
# Processing Record 217 | sao marcos
# Processing Record 218 | urumqi
# City not found. Skipping...
# Processing Record 219 | ouesso
# Processing Record 220 | bahia blanca
# Processing Record 221 | mogadishu
# Processing Record 222 | mazamari
# Processing Record 223 | hay river
# Processing Record 224 | sur
# Processing Record 225 | yaan
# Processing Record 226 | marzuq
# Processing Record 227 | leningradskiy
# Processing Record 228 | thompson
# Processing Record 229 | manta
# Processing Record 230 | saint-pierre
# Processing Record 231 | tawkar
# City not found. Skipping...
# Processing Record 232 | riyadh
# Processing Record 233 | villa carlos paz
# Processing Record 234 | marcona
# City not found. Skipping...
# Processing Record 235 | adrar
# Processing Record 236 | atikokan
# Processing Record 237 | cap malheureux
# Processing Record 238 | agadez
# Processing Record 239 | caohai
# Processing Record 240 | ambovombe
# Processing Record 241 | tapiramuta
# Processing Record 242 | warqla
# City not found. Skipping...
# Processing Record 243 | tumannyy
# City not found. Skipping...
# Processing Record 244 | hovd
# Processing Record 245 | pultusk
# Processing Record 246 | alofi
# Processing Record 247 | adiake
# Processing Record 248 | vila franca do campo
# Processing Record 249 | klembivka
# Processing Record 250 | lapeer
# Processing Record 251 | friedberg
# Processing Record 252 | bosaso
# Processing Record 253 | kuznechnoye
# Processing Record 254 | seoul
# Processing Record 255 | chignahuapan
# Processing Record 256 | sao felix do xingu
# Processing Record 257 | korla
# City not found. Skipping...
# Processing Record 258 | kulhudhuffushi
# Processing Record 259 | kutum
# Processing Record 260 | souillac
# Processing Record 261 | dingle
# Processing Record 262 | emerald
# Processing Record 263 | kyshtovka
# Processing Record 264 | tarudant
# City not found. Skipping...
# Processing Record 265 | kijang
# Processing Record 266 | gloucester
# Processing Record 267 | san isidro
# Processing Record 268 | warrenton
# Processing Record 269 | kavieng
# Processing Record 270 | raga
# City not found. Skipping...
# Processing Record 271 | goulburn
# Processing Record 272 | yenagoa
# Processing Record 273 | talcahuano
# Processing Record 274 | pathein
# Processing Record 275 | grand river south east
# City not found. Skipping...
# Processing Record 276 | itarema
# Processing Record 277 | ust-nera
# Processing Record 278 | viedma
# Processing Record 279 | kodiak
# Processing Record 280 | aliwal north
# Processing Record 281 | mount gambier
# Processing Record 282 | killybegs
# Processing Record 283 | san angelo
# Processing Record 284 | torbay
# Processing Record 285 | bur gabo
# City not found. Skipping...
# Processing Record 286 | berlevag
# Processing Record 287 | ilulissat
# Processing Record 288 | wulanhaote
# City not found. Skipping...
# Processing Record 289 | mezen
# Processing Record 290 | lixourion
# Processing Record 291 | kostomuksha
# Processing Record 292 | muli
# Processing Record 293 | coquimbo
# Processing Record 294 | kununurra
# Processing Record 295 | kavaratti
# Processing Record 296 | lasa
# Processing Record 297 | henderson
# Processing Record 298 | novoilinsk
# City not found. Skipping...
# Processing Record 299 | ajra
# Processing Record 300 | gorin
# Processing Record 301 | coolum beach
# Processing Record 302 | rawannawi
# City not found. Skipping...
# Processing Record 303 | esperance
# Processing Record 304 | paranaiba
# Processing Record 305 | pitimbu
# Processing Record 306 | daru
# Processing Record 307 | pyay
# Processing Record 308 | mamallapuram
# Processing Record 309 | ginir
# Processing Record 310 | semey
# Processing Record 311 | solnechnyy
# Processing Record 312 | mustafakemalpasa
# City not found. Skipping...
# Processing Record 313 | sambava
# Processing Record 314 | punta alta
# Processing Record 315 | roebourne
# Processing Record 316 | lerwick
# Processing Record 317 | saskylakh
# Processing Record 318 | jitra
# Processing Record 319 | bridlington
# Processing Record 320 | nathdwara
# Processing Record 321 | bambous virieux
# Processing Record 322 | nampula
# Processing Record 323 | nuuk
# Processing Record 324 | key west
# Processing Record 325 | bilibino
# Processing Record 326 | xining
# Processing Record 327 | hualmay
# Processing Record 328 | bengkulu
# City not found. Skipping...
# Processing Record 329 | toora-khem
# Processing Record 330 | dombarovskiy
# Processing Record 331 | voh
# Processing Record 332 | kokopo
# Processing Record 333 | dunkwa
# Processing Record 334 | caravelas
# Processing Record 335 | sechura
# Processing Record 336 | balabac
# Processing Record 337 | linares
# Processing Record 338 | oktyabrskiy
# Processing Record 339 | port-gentil
# Processing Record 340 | marsa matruh
# Processing Record 341 | majene
# Processing Record 342 | ranong
# Processing Record 343 | mtimbira
# Processing Record 344 | benguela
# Processing Record 345 | zharkent
# Processing Record 346 | hasaki
# Processing Record 347 | arua
# Processing Record 348 | san carlos de bariloche
# Processing Record 349 | curumani
# Processing Record 350 | altay
# Processing Record 351 | chake chake
# Processing Record 352 | ostrovnoy
# Processing Record 353 | puerto carreno
# Processing Record 354 | nelson bay
# Processing Record 355 | kahului
# Processing Record 356 | dikson
# Processing Record 357 | ust-tsilma
# Processing Record 358 | airai
# Processing Record 359 | port hardy
# Processing Record 360 | priyutovo
# Processing Record 361 | santander de quilichao
# Processing Record 362 | esmeraldas
# Processing Record 363 | kyzyl-suu
# Processing Record 364 | opuwo
# Processing Record 365 | zalantun
# Processing Record 366 | dzhusaly
# City not found. Skipping...
# Processing Record 367 | samusu
# City not found. Skipping...
# Processing Record 368 | plouzane
# Processing Record 369 | seidu
# Processing Record 370 | atasu
# Processing Record 371 | olafsvik
# City not found. Skipping...
# Processing Record 372 | cockburn town
# Processing Record 373 | lunenburg
# Processing Record 374 | camana
# City not found. Skipping...
# Processing Record 375 | pandan
# Processing Record 376 | cairns
# Processing Record 377 | tagusao
# Processing Record 378 | jalu
# Processing Record 379 | umzimvubu
# City not found. Skipping...
# Processing Record 380 | nurota
# Processing Record 381 | aktash
# City not found. Skipping...
# Processing Record 382 | bababe
# City not found. Skipping...
# Processing Record 383 | shadrinsk
# Processing Record 384 | kazalinsk
# City not found. Skipping...
# Processing Record 385 | biloela
# Processing Record 386 | ballinrobe
# Processing Record 387 | lata
# Processing Record 388 | terrace bay
# Processing Record 389 | canutama
# Processing Record 390 | yangjiang
# Processing Record 391 | wangdiphodrang
# City not found. Skipping...
# Processing Record 392 | pilao arcado
# City not found. Skipping...
# Processing Record 393 | severobaykalsk
# Processing Record 394 | bafq
# Processing Record 395 | udachnyy
# Processing Record 396 | isangel
# Processing Record 397 | baykit
# Processing Record 398 | ajdabiya
# Processing Record 399 | sibolga
# Processing Record 400 | yulara
# Processing Record 401 | saint anthony
# Processing Record 402 | grand forks
# Processing Record 403 | miyang
# Processing Record 404 | cockburn harbour
# City not found. Skipping...
# Processing Record 405 | leshukonskoye
# Processing Record 406 | mao
# Processing Record 407 | kerouane
# Processing Record 408 | songea
# Processing Record 409 | senneterre
# Processing Record 410 | vestmannaeyjar
# Processing Record 411 | sampit
# Processing Record 412 | vardo
# Processing Record 413 | palabuhanratu
# City not found. Skipping...
# Processing Record 414 | tual
# Processing Record 415 | moses lake
# Processing Record 416 | brae
# Processing Record 417 | praia da vitoria
# Processing Record 418 | kemin
# Processing Record 419 | awbari
# Processing Record 420 | cururupu
# Processing Record 421 | waingapu
# Processing Record 422 | cilegon
# Processing Record 423 | hervey bay
# Processing Record 424 | pitiquito
# Processing Record 425 | andenes
# City not found. Skipping...
# Processing Record 426 | wahran
# City not found. Skipping...
# Processing Record 427 | orichi
# Processing Record 428 | atar
# Processing Record 429 | constitucion
# Processing Record 430 | porosozero
# Processing Record 431 | topolobampo
# Processing Record 432 | necochea
# Processing Record 433 | mullaitivu
# City not found. Skipping...
# Processing Record 434 | ilebo
# Processing Record 435 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 436 | kempsey
# Processing Record 437 | khandyga
# Processing Record 438 | walvis bay
# Processing Record 439 | hurghada
# City not found. Skipping...
# Processing Record 440 | stawell
# Processing Record 441 | san sebastian
# Processing Record 442 | nemuro
# Processing Record 443 | baryatino
# Processing Record 444 | camacha
# Processing Record 445 | hambantota
# Processing Record 446 | coahuayana
# Processing Record 447 | seymchan
# Processing Record 448 | la rochelle
# Processing Record 449 | san andres
# Processing Record 450 | lukovetskiy
# Processing Record 451 | kaoma
# Processing Record 452 | banda aceh
# Processing Record 453 | hobyo
# Processing Record 454 | college
# Processing Record 455 | lundazi
# Processing Record 456 | bom jardim
# Processing Record 457 | yeppoon
# Processing Record 458 | solwezi
# Processing Record 459 | most
# Processing Record 460 | najran
# Processing Record 461 | porto novo
# Processing Record 462 | aklavik
# Processing Record 463 | atocha
# Processing Record 464 | srednekolymsk
# Processing Record 465 | aykhal
# Processing Record 466 | burnie
# Processing Record 467 | shakawe
# Processing Record 468 | tuggurt
# City not found. Skipping...
# Processing Record 469 | porto santo
# City not found. Skipping...
# Processing Record 470 | zilair
# Processing Record 471 | kaitangata
# Processing Record 472 | christchurch
# Processing Record 473 | sao joao da barra
# Processing Record 474 | sidi ali
# Processing Record 475 | yokadouma
# Processing Record 476 | nhulunbuy
# Processing Record 477 | aquiraz
# Processing Record 478 | comodoro rivadavia
# Processing Record 479 | dong xoai
# Processing Record 480 | hirara
# Processing Record 481 | north bend
# Processing Record 482 | hamilton
# Processing Record 483 | grand gaube
# Processing Record 484 | hailar
# Processing Record 485 | wanning
# Processing Record 486 | korem
# Processing Record 487 | tottori
# Processing Record 488 | corn island
# Processing Record 489 | hlotse
# City not found. Skipping...
# Processing Record 490 | yar-sale
# Processing Record 491 | la ronge
# Processing Record 492 | touros
# Processing Record 493 | teya
# Processing Record 494 | fairbanks
# Processing Record 495 | yasnogorsk
# Processing Record 496 | sosnovka
# Processing Record 497 | ponta delgada
# Processing Record 498 | cuamba
# Processing Record 499 | salalah
# Processing Record 500 | lavrentiya
# Processing Record 501 | yatou
# Processing Record 502 | messina
# Processing Record 503 | komsomolskiy
# Processing Record 504 | yerbogachen
# Processing Record 505 | harper
# Processing Record 506 | saint-augustin
# Processing Record 507 | indiana
# Processing Record 508 | lavumisa
# Processing Record 509 | mildura
# Processing Record 510 | borogontsy
# Processing Record 511 | jiwani
# Processing Record 512 | roma
# Processing Record 513 | kaohsiung
# Processing Record 514 | lyuban
# Processing Record 515 | axim
# Processing Record 516 | beringovskiy
# Processing Record 517 | serenje
# Processing Record 518 | bahir dar
# Processing Record 519 | baruun-urt
# Processing Record 520 | sarab
# Processing Record 521 | kukes
# Processing Record 522 | homer
# Processing Record 523 | kinkala
# Processing Record 524 | edea
# Processing Record 525 | broken hill
# Processing Record 526 | mercedes
# Processing Record 527 | joensuu
# Processing Record 528 | ihosy
# Processing Record 529 | slidell
# Processing Record 530 | poum
# Processing Record 531 | yarmouth
# Processing Record 532 | nouadhibou
# Processing Record 533 | otjimbingwe
# Processing Record 534 | yumen
# Processing Record 535 | lethem
# Processing Record 536 | makinsk
# Processing Record 537 | laguna
# Processing Record 538 | alekseyevskaya
# Processing Record 539 | njombe
# Processing Record 540 | taoudenni
# Processing Record 541 | tocopilla
# Processing Record 542 | vitim
# Processing Record 543 | cirie
# Processing Record 544 | ljubimec
# City not found. Skipping...
# Processing Record 545 | gardner
# Processing Record 546 | nurma
# Processing Record 547 | kitimat
# Processing Record 548 | san borja
# Processing Record 549 | olavarria
# Processing Record 550 | sorong
# Processing Record 551 | alice town
# Processing Record 552 | nguiu
# City not found. Skipping...
# Processing Record 553 | la crosse
# Processing Record 554 | kandrian
# Processing Record 555 | richards bay
# Processing Record 556 | ketchenery
# City not found. Skipping...
# Processing Record 557 | sisimiut
# Processing Record 558 | jinchengjiang
# City not found. Skipping...
# Processing Record 559 | acarau
# City not found. Skipping...
# Processing Record 560 | annigeri
# Processing Record 561 | belyy yar
# Processing Record 562 | sobolevo
# Processing Record 563 | iquique
# Processing Record 564 | kirkuk
# Processing Record 565 | whitehorse
# Processing Record 566 | srandakan
# Processing Record 567 | kazerun
# Processing Record 568 | puerto ayacucho
# Processing Record 569 | gilgit
# Processing Record 570 | correntina
# Processing Record 571 | charyshskoye
# Processing Record 572 | along
# Processing Record 573 | suluq
# Processing Record 574 | mujiayingzi
# Processing Record 575 | hami
# Processing Record 576 | ishigaki
# Processing Record 577 | moravske budejovice
# Processing Record 578 | rize
# Processing Record 579 | biak
# Processing Record 580 | santa luzia
# Processing Record 581 | kloulklubed
# Processing Record 582 | portree
# Processing Record 583 | gamba
# Processing Record 584 | hokitika
# Processing Record 585 | kilindoni
# Processing Record 586 | zuwarah
# Processing Record 587 | grand-santi
# Processing Record 588 | faya
# Processing Record 589 | boralday
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Convert Raw Data to DataFrame

# %%
weather_df = pd.DataFrame({"City" : date, "Cloudiness" : cloudiness, "Country" : country, "Date" : date,
                           "Humidity" : humidity, "Lat" : lat, "Lng" : lng, "Max Temp" : max_temp,
                           "Wind Speed" : wind_speed})

# Convert to CSV and export

weather_df.count()
#weather_df.head()
# Out:
# City          523
# Cloudiness    523
# Country       523
# Date          523
# Humidity      523
# Lat           523
# Lng           523
# Max Temp      523
# Wind Speed    523
# dtype: int64

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Max Temp"], weather_df["Lat"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 1, linewidth = 1.5)
plt.grid()
plt.title("City Latitude vs. Max Temperature (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt
#plt.savefig()
# Out:
# <module 'matplotlib.pyplot' from '/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 1, linewidth = 1.5)
plt.grid()
plt.title("City Latitude vs. Humidity (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt
#plt.savefig()
# Out:
# <module 'matplotlib.pyplot' from '/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 1, linewidth = 1.5)
plt.grid()
plt.title("City Latitude vs. Cloudiness (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt
#plt.savefig()
# Out:
# <module 'matplotlib.pyplot' from '/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Wind Speed (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
#plt.savefig()
