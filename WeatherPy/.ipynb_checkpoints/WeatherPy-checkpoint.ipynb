# %% [markdown]
# # WeatherPy

# %% [markdown]
# ## Analysis
# - As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# - There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# - There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import CitiPy
from citipy import citipy

# Import API key
from api_keys import api_key

# Output File (CSV)
output_data_file = "cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"City Count: {len(cities)}")
# Out:
# City Count: 600

# %% [markdown]
# ## Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = "709eaff6487fadf0c26e0bc441b8c854"

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
city_name = []

print("Beginning Data Retrival \n-----------------------------")

for i in range(len(cities)):
    try:     
        print(f"Processing Record {i + 1} | {cities[i]}")
        query_url = url + "appid=" + api_key + "&q=" + cities[i] + "&units=imperial"
        weather_response = requests.get(query_url).json()
        cloudiness.append(weather_response["clouds"]["all"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        humidity.append(weather_response["main"]["humidity"])
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
        city_name.append(weather_response["name"])
    except:
        print("City not found. Skipping...")
    
print("----------------------------- \nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrival
# -----------------------------
# Processing Record 1 | provideniya
# Processing Record 2 | byron bay
# Processing Record 3 | jamestown
# Processing Record 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 | tokmak
# Processing Record 6 | ushuaia
# Processing Record 7 | channagiri
# Processing Record 8 | tuktoyaktuk
# Processing Record 9 | kodiak
# Processing Record 10 | guerrero negro
# Processing Record 11 | hasaki
# Processing Record 12 | yulara
# Processing Record 13 | the valley
# Processing Record 14 | bluff
# Processing Record 15 | yar-sale
# Processing Record 16 | mataura
# Processing Record 17 | pisco
# Processing Record 18 | lorengau
# Processing Record 19 | tura
# Processing Record 20 | khatanga
# Processing Record 21 | fortuna
# Processing Record 22 | barentsburg
# City not found. Skipping...
# Processing Record 23 | rikitea
# Processing Record 24 | kapaa
# Processing Record 25 | dinar
# Processing Record 26 | hilo
# Processing Record 27 | katsuura
# Processing Record 28 | tasiilaq
# Processing Record 29 | bredasdorp
# Processing Record 30 | diamantino
# Processing Record 31 | trincomalee
# Processing Record 32 | najran
# Processing Record 33 | hobart
# Processing Record 34 | taolanaro
# City not found. Skipping...
# Processing Record 35 | erzin
# Processing Record 36 | butaritari
# Processing Record 37 | punta arenas
# Processing Record 38 | takoradi
# Processing Record 39 | fairbanks
# Processing Record 40 | albany
# Processing Record 41 | cape town
# Processing Record 42 | taoudenni
# Processing Record 43 | yellowknife
# Processing Record 44 | attawapiskat
# City not found. Skipping...
# Processing Record 45 | puerto ayora
# Processing Record 46 | vaini
# Processing Record 47 | sobolevo
# Processing Record 48 | chake chake
# Processing Record 49 | busselton
# Processing Record 50 | kaitangata
# Processing Record 51 | vaitupu
# City not found. Skipping...
# Processing Record 52 | dagami
# Processing Record 53 | port alfred
# Processing Record 54 | geraldton
# Processing Record 55 | hithadhoo
# Processing Record 56 | kloulklubed
# Processing Record 57 | saskylakh
# Processing Record 58 | flinders
# Processing Record 59 | margate
# Processing Record 60 | husavik
# Processing Record 61 | hermanus
# Processing Record 62 | san patricio
# Processing Record 63 | turan
# Processing Record 64 | nhulunbuy
# Processing Record 65 | palafrugell
# Processing Record 66 | camana
# City not found. Skipping...
# Processing Record 67 | tiksi
# Processing Record 68 | mar del plata
# Processing Record 69 | goya
# Processing Record 70 | laiagam
# City not found. Skipping...
# Processing Record 71 | cherskiy
# Processing Record 72 | guamuchil
# Processing Record 73 | avarua
# Processing Record 74 | esperance
# Processing Record 75 | qaanaaq
# Processing Record 76 | touros
# Processing Record 77 | mbandaka
# Processing Record 78 | ndele
# City not found. Skipping...
# Processing Record 79 | kuche
# City not found. Skipping...
# Processing Record 80 | grand river south east
# City not found. Skipping...
# Processing Record 81 | kirakira
# Processing Record 82 | saldanha
# Processing Record 83 | naze
# Processing Record 84 | thakurgaon
# Processing Record 85 | saint george
# Processing Record 86 | inirida
# Processing Record 87 | uruzgan
# Processing Record 88 | te anau
# Processing Record 89 | ilulissat
# Processing Record 90 | barrow
# Processing Record 91 | east london
# Processing Record 92 | havoysund
# Processing Record 93 | flin flon
# Processing Record 94 | luangwa
# Processing Record 95 | eyl
# Processing Record 96 | pevek
# Processing Record 97 | wewak
# Processing Record 98 | port-gentil
# Processing Record 99 | ugoofaaru
# Processing Record 100 | north bend
# Processing Record 101 | lebu
# Processing Record 102 | suihua
# Processing Record 103 | cabo san lucas
# Processing Record 104 | secunda
# Processing Record 105 | nikolskoye
# Processing Record 106 | alice springs
# Processing Record 107 | lasa
# Processing Record 108 | kapoeta
# City not found. Skipping...
# Processing Record 109 | satitoa
# City not found. Skipping...
# Processing Record 110 | spirit river
# Processing Record 111 | pemba
# Processing Record 112 | kamenskoye
# City not found. Skipping...
# Processing Record 113 | xiongyue
# Processing Record 114 | ariquemes
# Processing Record 115 | port elizabeth
# Processing Record 116 | kosonsoy
# Processing Record 117 | perth
# Processing Record 118 | kailua
# Processing Record 119 | wajima
# Processing Record 120 | ternate
# Processing Record 121 | sitka
# Processing Record 122 | dicabisagan
# Processing Record 123 | upernavik
# Processing Record 124 | chokurdakh
# Processing Record 125 | hervey bay
# Processing Record 126 | korla
# City not found. Skipping...
# Processing Record 127 | nizwa
# Processing Record 128 | san jeronimo
# Processing Record 129 | salalah
# Processing Record 130 | jinchang
# Processing Record 131 | azad shahr
# City not found. Skipping...
# Processing Record 132 | ampanihy
# Processing Record 133 | izhma
# Processing Record 134 | hamilton
# Processing Record 135 | mahebourg
# Processing Record 136 | ambodifototra
# City not found. Skipping...
# Processing Record 137 | atuona
# Processing Record 138 | faanui
# Processing Record 139 | lipari
# Processing Record 140 | meyungs
# City not found. Skipping...
# Processing Record 141 | naqadeh
# Processing Record 142 | talnakh
# Processing Record 143 | sept-iles
# Processing Record 144 | arraial do cabo
# Processing Record 145 | kahului
# Processing Record 146 | shenzhen
# Processing Record 147 | loikaw
# Processing Record 148 | airai
# Processing Record 149 | saleaula
# City not found. Skipping...
# Processing Record 150 | belushya guba
# City not found. Skipping...
# Processing Record 151 | bengkulu
# City not found. Skipping...
# Processing Record 152 | anadyr
# Processing Record 153 | bubaque
# Processing Record 154 | gigmoto
# Processing Record 155 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 156 | san policarpo
# Processing Record 157 | dingle
# Processing Record 158 | amapa
# Processing Record 159 | bathsheba
# Processing Record 160 | chicama
# Processing Record 161 | bethel
# Processing Record 162 | clearlake
# Processing Record 163 | vila velha
# Processing Record 164 | piacabucu
# Processing Record 165 | severo-kurilsk
# Processing Record 166 | nouakchott
# Processing Record 167 | codrington
# Processing Record 168 | garowe
# Processing Record 169 | new norfolk
# Processing Record 170 | saint-philippe
# Processing Record 171 | krasnoborsk
# Processing Record 172 | clarksville
# Processing Record 173 | cockburn harbour
# City not found. Skipping...
# Processing Record 174 | samusu
# City not found. Skipping...
# Processing Record 175 | quelimane
# Processing Record 176 | bairiki
# City not found. Skipping...
# Processing Record 177 | cay
# Processing Record 178 | santana
# Processing Record 179 | petukhovo
# Processing Record 180 | mandalgovi
# Processing Record 181 | amderma
# City not found. Skipping...
# Processing Record 182 | leningradskiy
# Processing Record 183 | blonduos
# City not found. Skipping...
# Processing Record 184 | thinadhoo
# Processing Record 185 | adrar
# Processing Record 186 | santa fe
# Processing Record 187 | castro
# Processing Record 188 | tidore
# City not found. Skipping...
# Processing Record 189 | agha jari
# City not found. Skipping...
# Processing Record 190 | maniitsoq
# Processing Record 191 | dunedin
# Processing Record 192 | kavieng
# Processing Record 193 | kroya
# Processing Record 194 | utiroa
# City not found. Skipping...
# Processing Record 195 | alofi
# Processing Record 196 | beringovskiy
# Processing Record 197 | luderitz
# Processing Record 198 | klaksvik
# Processing Record 199 | rawson
# Processing Record 200 | poya
# Processing Record 201 | dawlatabad
# Processing Record 202 | banjar
# Processing Record 203 | iqaluit
# Processing Record 204 | nianzishan
# Processing Record 205 | gamboma
# Processing Record 206 | bilma
# Processing Record 207 | novokruchininskiy
# Processing Record 208 | buritis
# Processing Record 209 | nioro
# Processing Record 210 | victoria
# Processing Record 211 | kontagora
# Processing Record 212 | miri
# Processing Record 213 | ponta do sol
# Processing Record 214 | ouro preto do oeste
# Processing Record 215 | constitucion
# Processing Record 216 | dudinka
# Processing Record 217 | souillac
# Processing Record 218 | asau
# City not found. Skipping...
# Processing Record 219 | chuy
# Processing Record 220 | richards bay
# Processing Record 221 | tateyama
# Processing Record 222 | play cu
# City not found. Skipping...
# Processing Record 223 | daru
# Processing Record 224 | otradnoye
# Processing Record 225 | lavrentiya
# Processing Record 226 | hit
# Processing Record 227 | esna
# Processing Record 228 | faya
# Processing Record 229 | uwayl
# City not found. Skipping...
# Processing Record 230 | dzhebariki-khaya
# Processing Record 231 | osoyoos
# Processing Record 232 | samarai
# Processing Record 233 | abu samrah
# Processing Record 234 | puerto escondido
# Processing Record 235 | nguiu
# City not found. Skipping...
# Processing Record 236 | okakarara
# Processing Record 237 | kruisfontein
# Processing Record 238 | nyurba
# Processing Record 239 | watsa
# Processing Record 240 | belmonte
# Processing Record 241 | sompeta
# Processing Record 242 | cayenne
# Processing Record 243 | thompson
# Processing Record 244 | georgetown
# Processing Record 245 | portland
# Processing Record 246 | corbelia
# Processing Record 247 | batemans bay
# Processing Record 248 | goure
# Processing Record 249 | pindiga
# Processing Record 250 | zlatoustovsk
# City not found. Skipping...
# Processing Record 251 | seymchan
# Processing Record 252 | high prairie
# Processing Record 253 | saint-augustin
# Processing Record 254 | zhigansk
# Processing Record 255 | sinnamary
# Processing Record 256 | leamington
# Processing Record 257 | cuiluan
# Processing Record 258 | chapais
# Processing Record 259 | algarrobo
# Processing Record 260 | cam ranh
# Processing Record 261 | isangel
# Processing Record 262 | marcona
# City not found. Skipping...
# Processing Record 263 | cabrero
# Processing Record 264 | praia da vitoria
# Processing Record 265 | tsihombe
# City not found. Skipping...
# Processing Record 266 | kudahuvadhoo
# Processing Record 267 | guarapari
# Processing Record 268 | umm kaddadah
# Processing Record 269 | ewing
# Processing Record 270 | tumannyy
# City not found. Skipping...
# Processing Record 271 | uige
# Processing Record 272 | yugorsk
# Processing Record 273 | kandi
# Processing Record 274 | aykhal
# Processing Record 275 | pafos
# City not found. Skipping...
# Processing Record 276 | walvis bay
# Processing Record 277 | hohhot
# Processing Record 278 | ribeira grande
# Processing Record 279 | manta
# Processing Record 280 | bodmin
# Processing Record 281 | hashtrud
# Processing Record 282 | touho
# Processing Record 283 | sao filipe
# Processing Record 284 | kayerkan
# Processing Record 285 | farsund
# Processing Record 286 | nouadhibou
# Processing Record 287 | iquique
# Processing Record 288 | longyearbyen
# Processing Record 289 | karratha
# Processing Record 290 | teya
# Processing Record 291 | port macquarie
# Processing Record 292 | pryazha
# Processing Record 293 | kitimat
# Processing Record 294 | tezu
# Processing Record 295 | cap malheureux
# Processing Record 296 | cilegon
# Processing Record 297 | nome
# Processing Record 298 | okha
# Processing Record 299 | vathi
# Processing Record 300 | garhi khairo
# Processing Record 301 | lalibela
# Processing Record 302 | la ligua
# Processing Record 303 | port blair
# Processing Record 304 | acapulco
# Processing Record 305 | ucluelet
# Processing Record 306 | sorland
# Processing Record 307 | banamba
# Processing Record 308 | sao joao da barra
# Processing Record 309 | tual
# Processing Record 310 | rapid valley
# Processing Record 311 | ambilobe
# Processing Record 312 | port hardy
# Processing Record 313 | manbij
# Processing Record 314 | alekseyevka
# Processing Record 315 | nyimba
# Processing Record 316 | yaring
# Processing Record 317 | westport
# Processing Record 318 | ksenyevka
# City not found. Skipping...
# Processing Record 319 | tayzhina
# Processing Record 320 | lakes entrance
# Processing Record 321 | mana
# Processing Record 322 | high level
# Processing Record 323 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 324 | wasilla
# Processing Record 325 | lata
# Processing Record 326 | kikwit
# Processing Record 327 | abu kamal
# Processing Record 328 | vestmannaeyjar
# Processing Record 329 | coxim
# Processing Record 330 | half moon bay
# Processing Record 331 | dok kham tai
# Processing Record 332 | rabo de peixe
# Processing Record 333 | ancud
# Processing Record 334 | solnechnyy
# Processing Record 335 | lipin bor
# Processing Record 336 | monrovia
# Processing Record 337 | halifax
# Processing Record 338 | aklavik
# Processing Record 339 | crotone
# Processing Record 340 | sur
# Processing Record 341 | mogadishu
# Processing Record 342 | tavares
# Processing Record 343 | tomioka
# Processing Record 344 | groningen
# Processing Record 345 | lagoa
# Processing Record 346 | rungata
# City not found. Skipping...
# Processing Record 347 | nador
# Processing Record 348 | loreto
# Processing Record 349 | carnarvon
# Processing Record 350 | ngorongoro
# Processing Record 351 | brae
# Processing Record 352 | henties bay
# Processing Record 353 | el carmen de bolivar
# Processing Record 354 | oksfjord
# Processing Record 355 | torbay
# Processing Record 356 | coro
# Processing Record 357 | la libertad
# Processing Record 358 | kattivakkam
# Processing Record 359 | los llanos de aridane
# Processing Record 360 | vardo
# Processing Record 361 | astana
# Processing Record 362 | corowa
# Processing Record 363 | nanortalik
# Processing Record 364 | villazon
# City not found. Skipping...
# Processing Record 365 | bolton
# Processing Record 366 | usolye
# Processing Record 367 | dikson
# Processing Record 368 | bambous virieux
# Processing Record 369 | tiarei
# Processing Record 370 | silver city
# Processing Record 371 | cairns
# Processing Record 372 | pacific grove
# Processing Record 373 | nizhneyansk
# City not found. Skipping...
# Processing Record 374 | kalmunai
# Processing Record 375 | zhuhai
# Processing Record 376 | abaza
# Processing Record 377 | rusape
# Processing Record 378 | tuatapere
# Processing Record 379 | mahabad
# Processing Record 380 | vila franca do campo
# Processing Record 381 | bestobe
# Processing Record 382 | maningrida
# Processing Record 383 | mount gambier
# Processing Record 384 | belyy yar
# Processing Record 385 | amga
# Processing Record 386 | kasongo-lunda
# Processing Record 387 | sao felix do xingu
# Processing Record 388 | grindavik
# Processing Record 389 | san quintin
# Processing Record 390 | mooi river
# City not found. Skipping...
# Processing Record 391 | mangan
# Processing Record 392 | coquimbo
# Processing Record 393 | verkhnevilyuysk
# Processing Record 394 | mayo
# Processing Record 395 | petropavlovsk-kamchatskiy
# Processing Record 396 | nuuk
# Processing Record 397 | bumba
# Processing Record 398 | puerto carreno
# Processing Record 399 | clyde river
# Processing Record 400 | bitam
# Processing Record 401 | vicuna
# City not found. Skipping...
# Processing Record 402 | mukhen
# Processing Record 403 | orlovskiy
# Processing Record 404 | jalpatagua
# Processing Record 405 | ayagoz
# Processing Record 406 | shimoda
# Processing Record 407 | cidreira
# Processing Record 408 | plattling
# Processing Record 409 | phuthaditjhaba
# Processing Record 410 | belaya gora
# Processing Record 411 | palatka
# Processing Record 412 | hofn
# Processing Record 413 | vung tau
# Processing Record 414 | washougal
# Processing Record 415 | galway
# Processing Record 416 | grafton
# Processing Record 417 | panambi
# Processing Record 418 | mixtequilla
# City not found. Skipping...
# Processing Record 419 | huangchuan
# Processing Record 420 | port hedland
# Processing Record 421 | katangli
# Processing Record 422 | port hawkesbury
# Processing Record 423 | kavaratti
# Processing Record 424 | batagay
# Processing Record 425 | noumea
# Processing Record 426 | pavlovskiy posad
# Processing Record 427 | carutapera
# Processing Record 428 | krasnoselkup
# City not found. Skipping...
# Processing Record 429 | develi
# Processing Record 430 | meulaboh
# Processing Record 431 | gravdal
# Processing Record 432 | la ronge
# Processing Record 433 | jhang
# Processing Record 434 | gamba
# Processing Record 435 | deputatskiy
# Processing Record 436 | nenagh
# Processing Record 437 | tuy hoa
# Processing Record 438 | yarada
# Processing Record 439 | norman wells
# Processing Record 440 | sancti spiritus
# Processing Record 441 | pangnirtung
# Processing Record 442 | smithers
# Processing Record 443 | magadi
# Processing Record 444 | vostok
# Processing Record 445 | tucuman
# Processing Record 446 | vechelde
# Processing Record 447 | tabiauea
# City not found. Skipping...
# Processing Record 448 | viedma
# Processing Record 449 | sahuaripa
# Processing Record 450 | kushima
# Processing Record 451 | ostrovnoy
# Processing Record 452 | parrita
# Processing Record 453 | tawkar
# City not found. Skipping...
# Processing Record 454 | hambantota
# Processing Record 455 | sola
# Processing Record 456 | karpogory
# Processing Record 457 | abeche
# Processing Record 458 | aksay
# Processing Record 459 | assens
# Processing Record 460 | ho
# City not found. Skipping...
# Processing Record 461 | were ilu
# Processing Record 462 | coffs harbour
# Processing Record 463 | sabla
# Processing Record 464 | coihaique
# Processing Record 465 | yetkul
# Processing Record 466 | jati
# Processing Record 467 | wajir
# Processing Record 468 | sungairaya
# Processing Record 469 | lolua
# City not found. Skipping...
# Processing Record 470 | sindhnur
# Processing Record 471 | nelson bay
# Processing Record 472 | gogrial
# City not found. Skipping...
# Processing Record 473 | temaraia
# City not found. Skipping...
# Processing Record 474 | sofiysk
# City not found. Skipping...
# Processing Record 475 | okhotsk
# Processing Record 476 | rundu
# Processing Record 477 | chepareria
# Processing Record 478 | tabas
# Processing Record 479 | provins
# Processing Record 480 | celestun
# Processing Record 481 | sabang
# Processing Record 482 | harper
# Processing Record 483 | banfora
# Processing Record 484 | muramatsu
# Processing Record 485 | sentyabrskiy
# City not found. Skipping...
# Processing Record 486 | buchanan
# Processing Record 487 | west bay
# Processing Record 488 | pargolovo
# Processing Record 489 | caravelas
# Processing Record 490 | bereda
# Processing Record 491 | komsomolets
# Processing Record 492 | athabasca
# Processing Record 493 | fort nelson
# Processing Record 494 | sumy
# Processing Record 495 | aksarka
# Processing Record 496 | mapiripan
# Processing Record 497 | isla mujeres
# Processing Record 498 | alzamay
# Processing Record 499 | anan
# Processing Record 500 | la concepcion
# Processing Record 501 | sao gabriel da cachoeira
# Processing Record 502 | haines junction
# Processing Record 503 | mombasa
# Processing Record 504 | gbadolite
# Processing Record 505 | bhusawal
# Processing Record 506 | lang son
# Processing Record 507 | dawei
# Processing Record 508 | praia
# Processing Record 509 | acari
# Processing Record 510 | saurimo
# Processing Record 511 | ust-kan
# Processing Record 512 | blackwater
# Processing Record 513 | sulangan
# Processing Record 514 | misratah
# Processing Record 515 | cozumel
# City not found. Skipping...
# Processing Record 516 | san cristobal
# Processing Record 517 | wawa
# Processing Record 518 | narsaq
# Processing Record 519 | brightwater
# Processing Record 520 | labutta
# City not found. Skipping...
# Processing Record 521 | manaus
# Processing Record 522 | bengkalis
# City not found. Skipping...
# Processing Record 523 | olafsvik
# City not found. Skipping...
# Processing Record 524 | beya
# Processing Record 525 | bara
# Processing Record 526 | tasbuget
# City not found. Skipping...
# Processing Record 527 | bafq
# Processing Record 528 | port augusta
# Processing Record 529 | joshimath
# Processing Record 530 | almansa
# Processing Record 531 | medina del campo
# Processing Record 532 | prado
# Processing Record 533 | ruwi
# Processing Record 534 | kindu
# Processing Record 535 | turbat
# Processing Record 536 | poplar bluff
# Processing Record 537 | bury saint edmunds
# City not found. Skipping...
# Processing Record 538 | abha
# Processing Record 539 | bayburt
# Processing Record 540 | dibrugarh
# Processing Record 541 | svetlogorsk
# Processing Record 542 | bridgeton
# Processing Record 543 | saint-joseph
# Processing Record 544 | mezen
# Processing Record 545 | beloha
# Processing Record 546 | junagarh
# Processing Record 547 | kjopsvik
# Processing Record 548 | padang
# Processing Record 549 | mahaicony
# City not found. Skipping...
# Processing Record 550 | mayskiy
# Processing Record 551 | aripuana
# Processing Record 552 | oranjemund
# Processing Record 553 | sao francisco
# Processing Record 554 | nemuro
# Processing Record 555 | honningsvag
# Processing Record 556 | warrensburg
# Processing Record 557 | ambon
# Processing Record 558 | yasnyy
# Processing Record 559 | dedougou
# Processing Record 560 | ardakan
# Processing Record 561 | alawalpur
# Processing Record 562 | santa isabel do rio negro
# Processing Record 563 | idrinskoye
# Processing Record 564 | khormuj
# City not found. Skipping...
# Processing Record 565 | dauphin
# Processing Record 566 | monte escobedo
# Processing Record 567 | ornskoldsvik
# Processing Record 568 | dunayivtsi
# City not found. Skipping...
# Processing Record 569 | shingu
# Processing Record 570 | yomitan
# City not found. Skipping...
# Processing Record 571 | aginskoye
# Processing Record 572 | picos
# Processing Record 573 | college
# Processing Record 574 | hami
# Processing Record 575 | palmer
# Processing Record 576 | ngukurr
# City not found. Skipping...
# Processing Record 577 | fare
# Processing Record 578 | kholodnyy
# Processing Record 579 | sorkjosen
# City not found. Skipping...
# Processing Record 580 | jizan
# Processing Record 581 | van
# Processing Record 582 | sao joao do piaui
# Processing Record 583 | montalvo
# Processing Record 584 | waipawa
# Processing Record 585 | saint-pierre
# Processing Record 586 | nakamura
# Processing Record 587 | davila
# Processing Record 588 | mugur-aksy
# Processing Record 589 | arman
# Processing Record 590 | fakse ladeplads
# Processing Record 591 | acarau
# City not found. Skipping...
# Processing Record 592 | ilhabela
# Processing Record 593 | golden
# Processing Record 594 | lere
# Processing Record 595 | ulaangom
# Processing Record 596 | kaputa
# Processing Record 597 | moose factory
# Processing Record 598 | zhezkazgan
# Processing Record 599 | homer
# Processing Record 600 | bobo dioulasso
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Convert Raw Data to DataFrame

# %%
# Convert to CSV and export
weather_df = pd.DataFrame({"City" : city_name, "Cloudiness" : cloudiness, "Country" : country, "Date" : date,
                           "Humidity" : humidity, "Lat" : lat, "Lng" : lng, "Max Temp" : max_temp,
                           "Wind Speed" : wind_speed})
weather_df.to_csv(path_or_buf=output_data_file,index=False,encoding="UTF-8")
#weather_df.count()
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Provideniya          92      RU  1549139992        94  64.42 -173.23
# 1    Byron Bay          90      AU  1549137600       100 -28.65  153.62
# 2    Jamestown           0      AU  1549139771        65 -33.21  138.60
# 3       Tokmak          88      UA  1549139980        96  47.26   35.70
# 4      Ushuaia          75      AR  1549137600        67 -54.81  -68.31
#
#    Max Temp  Wind Speed
# 0     32.41       37.58
# 1     73.40        3.36
# 2     67.29        6.60
# 3     38.12        6.82
# 4     59.00       20.80

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Max Temp"], weather_df["Lat"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Max Temperature (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.savefig("./Images/latvtemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Humidity (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("./Images/latvhumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Cloudiness (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("./Images/latvcloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Wind Speed (01/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("./Images/latvwindspeed.png")
plt.show()
